# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Setting path and doing data inpection.

# %%
Wages = pd.read_csv('/content/drive/MyDrive/wages.csv')

# %%
Wages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1379 entries, 0 to 1378
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   earn    1379 non-null   float64
#  1   height  1379 non-null   float64
#  2   sex     1379 non-null   object
#  3   race    1379 non-null   object
#  4   ed      1379 non-null   int64
#  5   age     1379 non-null   int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 64.8+ KB

# %%
Wages.isnull().sum()
# Out:
# earn      0
# height    0
# sex       0
# race      0
# ed        0
# age       0
# dtype: int64

# %%
Wages.head()
# Out:
#            earn  height     sex   race  ed  age
# 0  79571.299011   73.89    male  white  16   49
# 1  96396.988643   66.23  female  white  16   62
# 2  48710.666947   63.77  female  white  16   33
# 3  80478.096153   63.22  female  other  16   95
# 4  82089.345498   63.08  female  white  17   43

# %%
Wages['sex'].value_counts()
# Out:
# female    859
# male      520
# Name: sex, dtype: int64

# %%
Wages['race'].value_counts()
# Out:
# white       1147
# black        126
# hispanic      77
# other         29
# Name: race, dtype: int64

# %%
x= Wages['sex'].map({'female': 0 , 'male':1})

# %%
Wages['sex'] = x

# %%
Wages.head()
# Out:
#            earn  height  sex   race  ed  age
# 0  79571.299011   73.89    1  white  16   49
# 1  96396.988643   66.23    0  white  16   62
# 2  48710.666947   63.77    0  white  16   33
# 3  80478.096153   63.22    0  other  16   95
# 4  82089.345498   63.08    0  white  17   43

# %%
#y=Wages['race'].map({'white':1,'black':2,'hispanic':3,'other':4})

# %%
#Wages['race']  = y

# %%
Wages['ed'].value_counts()
# Out:
# 12    520
# 14    192
# 16    187
# 13    119
# 18     80
# 17     70
# 15     66
# 11     39
# 10     37
# 8      28
# 9      23
# 6       7
# 5       5
# 7       3
# 4       2
# 3       1
# Name: ed, dtype: int64

# %%
Wages.describe()
# Out:
#                 earn       height          sex           ed          age
# count    1379.000000  1379.000000  1379.000000  1379.000000  1379.000000
# mean    32446.292622    66.592640     0.377085    13.354605    45.328499
# std     31257.070006     3.818108     0.484832     2.438741    15.789715
# min       -98.580489    57.340000     0.000000     3.000000    22.000000
# 25%     10538.790721    63.720000     0.000000    12.000000    33.000000
# 50%     26877.870178    66.050000     0.000000    13.000000    42.000000
# 75%     44506.215336    69.315000     1.000000    15.000000    55.000000
# max    317949.127955    77.210000     1.000000    18.000000    95.000000

# %%
Wages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1379 entries, 0 to 1378
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   earn    1379 non-null   float64
#  1   height  1379 non-null   float64
#  2   sex     1379 non-null   int64
#  3   race    1379 non-null   object
#  4   ed      1379 non-null   int64
#  5   age     1379 non-null   int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 64.8+ KB

# %%
Wages.head()
# Out:
#            earn  height  sex   race  ed  age
# 0  79571.299011   73.89    1  white  16   49
# 1  96396.988643   66.23    0  white  16   62
# 2  48710.666947   63.77    0  white  16   33
# 3  80478.096153   63.22    0  other  16   95
# 4  82089.345498   63.08    0  white  17   43

# %% [markdown]
# # EDA

# %%
sns.countplot(x = 'race',hue = 'sex',data=Wages) # considering categorical variable with numeric.

# %% [markdown]
# Show value counts for a single categorical variable:

# %%
sns.set_theme(style='darkgrid')
#Wages = sns.load_dataset('Wages')
sns.countplot(x = 'race',data = Wages)

# %% [markdown]
# Changing the colour style

# %%
sns.set_theme(style='darkgrid')
#Wages = sns.load_dataset('Wages')
sns.countplot(x = 'race',data = Wages,palette="Set3")

# %%
sns.countplot(x='sex',data=Wages) #where 0 is female and 1 is male.

# %%
sns.countplot(x = 'race',data = Wages, facecolor =(0,0,0,0),linewidth = 5, edgecolor=sns.color_palette("dark", 3))

# %%
sns.catplot(x = 'race',hue = 'sex',data=Wages,col = 'sex',kind='count')

# %%
sns.set_theme(style='ticks')
#df = sns.load_dataset("Wages")
sns.pairplot(Wages , hue = 'sex')

# %%
#sns.set_theme(style='ticks')
#df = sns.load_dataset("Wages")
#sns.pairplot(Wages , hue = 'earn')

# %%
w= sns.PairGrid(Wages)
w.map_diag(sns.histplot)
w.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(Wages)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot, lw=3, legend=False)

# %%
sns.relplot(x = 'age',y='ed',kind ='scatter',data=Wages)

# %%
sns.set_style("whitegrid")
sns.boxplot(x = Wages.ed,y= Wages.earn,data=Wages, palette="deep")
sns.despine(left=True)

# %%
#wages = sns.load_dataset("Wages")
sns.catplot(x="race", y="earn", data=Wages)

# %%
sns.catplot(x='earn',y='age',data=Wages)

# %%
sns.catplot(x='race',y='earn',kind='box',data=Wages)

# %%
sns.catplot(x='race',y='earn',hue = 'sex',kind='box',data=Wages)

# %%
sns.relplot(x='race', y = 'earn',hue='sex',style='sex',data=Wages)

# %% [markdown]
# # Checking the data

# %%
print(Wages.groupby('age').size())
# Out:
# age
# 22    25
# 23    17
# 24    19
# 25    30
# 26    31
#       ..
# 90     1
# 91     1
# 92     1
# 93     1
# 95     3
# Length: 73, dtype: int64

# %%
print(Wages.groupby('sex').size())
# Out:
# sex
# 0    859
# 1    520
# dtype: int64

# %%
print(Wages.groupby('ed').size())
# Out:
# ed
# 3       1
# 4       2
# 5       5
# 6       7
# 7       3
# 8      28
# 9      23
# 10     37
# 11     39
# 12    520
# 13    119
# 14    192
# 15     66
# 16    187
# 17     70
# 18     80
# dtype: int64

# %%
print(Wages.groupby('earn').size())
# Out:
# earn
# -98.580489        1
# -95.710279        1
# -66.128300        1
# -56.321979        1
# -49.597624        1
#                  ..
#  198835.433852    1
#  235388.719223    1
#  270275.894208    1
#  278213.531776    1
#  317949.127955    1
# Length: 1379, dtype: int64

# %%
print(Wages.groupby('height').size())
# Out:
# height
# 57.34    1
# 57.94    1
# 58.09    1
# 58.97    1
# 58.99    1
#         ..
# 76.68    1
# 76.73    1
# 77.02    1
# 77.12    1
# 77.21    1
# Length: 830, dtype: int64

# %%
print(Wages.groupby('race').size()) # same as value count
# Out:
# race
# black        126
# hispanic      77
# other         29
# white       1147
# dtype: int64

# %%
Wages.race.value_counts()   # same as size
# Out:
# white       1147
# black        126
# hispanic      77
# other         29
# Name: race, dtype: int64

# %%
e=print('Total:',Wages[Wages.earn<0].shape[0])
# Out:
# Total: 11

# %%
Wages_N = Wages[(Wages.earn>0)]
print(Wages_N.shape)
# Out:
# (1368, 6)

# %%
Wages_N.head()
# Out:
#            earn  height  sex   race  ed  age
# 0  79571.299011   73.89    1  white  16   49
# 1  96396.988643   66.23    0  white  16   62
# 2  48710.666947   63.77    0  white  16   33
# 3  80478.096153   63.22    0  other  16   95
# 4  82089.345498   63.08    0  white  17   43

# %%
sns.countplot(Wages_N.sex)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot(x = 'height',y='earn',hue='sex',kind='scatter',data=Wages_N)

# %%
sns.relplot(x = 'height',y='earn',hue='age',data=Wages_N)

# %%
# Correlation of heat map:
corr = Wages_N.corr()
print(corr)
sns.heatmap(corr)
# Out:
#             earn    height       sex        ed       age
# earn    1.000000  0.302335  0.351942  0.347204  0.064903
# height  0.302335  1.000000  0.702232  0.120278 -0.124153
# sex     0.351942  0.702232  1.000000  0.069738 -0.058673
# ed      0.347204  0.120278  0.069738  1.000000 -0.138270
# age     0.064903 -0.124153 -0.058673 -0.138270  1.000000

# %%
corrmat = Wages_N.corr()
top_features = corrmat.index
plt.figure(figsize=(15,10))
sns.heatmap(Wages_N[top_features].corr(),annot=True)

# %% [markdown]
# # Importing ML Algorithms and find best alogoritm for predicting.

# %%
# import the ML algorithm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.cluster import KMeans
import xgboost as xgb
from xgboost import XGBClassifier
from xgboost import plot_importance
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
import graphviz
from IPython.display import display

# import libraries for model validation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold 
# For accuracy
from sklearn.metrics import accuracy_score

# %%
feature_names = ['earn','height','ed','age']
X = Wages_N[feature_names]
y = Wages_N.sex

# %%
# Split the train and test data.
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33,random_state=0)

# %%
# Model Selection:
# Lets initialize the seven different classifier models with their default parameters and add them to a model 
#list as:
models = []
models.append(('KNN', KNeighborsClassifier()))
models.append(('SVC', SVC()))
models.append(('LR', LogisticRegression()))
models.append(('DT', DecisionTreeClassifier()))
models.append(('GNB', GaussianNB()))
models.append(('RF', RandomForestClassifier()))
models.append(('GB', GradientBoostingClassifier()))
models.append(('XGB', XGBClassifier()))

# %%
# Fitting of each model and calculation the accuracy of the respective model using the "accuracy_Score". 
names = []
scores = []
for name, model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    scores.append(accuracy_score(y_test, y_pred))
    names.append(name)
tr_split = pd.DataFrame({'Name': names, 'Score': scores})
print(tr_split)
# Out:
#   Name     Score
# 0  KNN  0.878319
# 1  SVC  0.674779
# 2   LR  0.743363
# 3   DT  0.780973
# 4  GNB  0.836283
# 5   RF  0.867257
# 6   GB  0.871681
# 7  XGB  0.869469

# %%
# K-Fold Cross Validation
# This method splits the data set into K equal partitions ("folds"), then 1 fold as the testing set and the union 
# of the other folds as the training set. Then the model is tested for accuracy. The process will follow the above steps
# K times, using different fold as the testing set each time. The average testing accuracyof the process is the testing 
# accuracy. 
# This method is more accurate estimate of out-of-sample accuracy. More "efficient" use of data (every observation 
# is used for both training and testing). The downside of this method is much slower than Train/Test split.We need more 
# computation capability for this method.

names = []
scores = []
for name, model in models:
    
    kfold = KFold(n_splits=10, random_state=10) 
    score = cross_val_score(model, X, y, cv=kfold, scoring='accuracy').mean()
    
    names.append(name)
    scores.append(score)
kf_cross_val = pd.DataFrame({'Name': names, 'Score': scores})
print(kf_cross_val)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# ...

# %% [markdown]
# By this we can say that KNN algorithm will give us the highest accuracy for predicting the sex variable(y).

# %%
sns.barplot(x='Name',y='Score',data=kf_cross_val)

# %% [markdown]
# **Thank You**
